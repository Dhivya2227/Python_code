# %%
#examine Expression and written type name
print(10/5,type(10/5))
print(5/10,type(5/10))
print(int(4//2),type(4//2))
print(10%4+8/4,type(10%4+8/4))
print(3**10/3,type(3**10/3))
# Out:
# 2.0 <class 'float'>
# 0.5 <class 'float'>
# 2 <class 'int'>
# 4.0 <class 'float'>
# 19683.0 <class 'float'>

# %%
#Translate code ..equivalent into py code
print((3+4)*(7))
n=6
print(n*(n-1)/2)
import math
a=2
b=1
math.sqrt(a*a+b*b)
# Out:
# 49
# 15.0
# 2.23606797749979

# %%
class signup:
    def __init__(self,username,password):
        self.password=password
        
        if "@" in username and "." in username:
            self.username=username
        else:
            self.username=None
    def display(self):
        print("Username",self.username)
        print("Password",self.password)
                
username=input("Enter your username")
password=input("Enter your password")
page=signup(username,password)
page.display()
# Out:
# Enter your username dhivyagmail.com
# Enter your password 1w234
# Username None
# Password 1w234

# %%
class Signup:
    def __init__(self, username, email, password, age):

        self.username = username
        self.password = password
        self.age = age

        # Email validation
        if "@" in email and "." in email:
            if 5 <= len(email) <= 30:
                self.email = email
                print("✅ Signup successful!")
                print(f"Welcome, {self.username} 🎉")
            else:
                print("❌ Email must be 5 to 30 characters long")
                self.email = None
        else:
            print("❌ Invalid email format")
            self.email = None

    def display_user(self):
        print("\n--- User Details ---")
        print("Username:", self.username)
        print("Email:", self.email)
        print("Age:", self.age)


# Input from user
username = input("Enter username: ")
email = input("Enter email: ")
password = input("Enter password: ")
age = int(input("Enter age: "))

# Create object
user1 = Signup(username, email, password, age)

# Display details
user1.display_user()
# Out:
# Enter username:  dhivya
# Enter email:  dhivya@gmail.com
# Enter password:  1234
# Enter age:  20
# ✅ Signup successful!
# Welcome, dhivya 🎉
#
# --- User Details ---
# Username: dhivya
# Email: dhivya@gmail.com
# Age: 20
