# %%
import os
print(os.getcwd())
print(os.getcwdb())
# Out:
# C:\Users\Admin
# b'C:\\Users\\Admin'

# %%
import os
os.chdir(r"D:\Apdf")
print(os.listdir())
print(os.getcwd())
#It changes only inside your program
#It does not move files
#It does not change system settings
#So Python moved from:C:\Users\Admin ➝ D:\Apdf
# Out:
# ['2.pdf', '2526-3882-msc-advanced-mechanical-engineering-science.odt', '26040600290109SBIN_ChallanReceipt.pdf', 'ashlora_jewellery_logo.svg', 'assignmentds-tab-db.pptx', 'automated%20dashboard%20report (Recovered).xlsx', 'CAN_37094132_4780950.pdf', 'CDSML.pdf', 'dharshini (1).xlsx', 'dharshini.xlsx', 'DHIVYADHARSHINI-R-FlowCV-Resume-20260207 (1) (1).pdf', 'Dhivyadharshinir aadhaar (1).pdf', 'Dhivyadharshinir aadhaar.jpeg', 'Dhivyadharshinir aadhaar.pdf', 'Dhivyadharshinir Birth (1).pdf', 'Dhivyadharshinir Birth.jpeg', 'Dhivyadharshinir Birth.pdf', 'Dhivyadharshinir hsc_marksheet (1).pdf', 'Dhivyadharshinir hsc_marksheet.jpeg', 'Dhivyadharshinir hsc_marksheet.pdf', 'Dhivyadharshinir income_certif (1).pdf', 'Dhivyadharshinir income_certif.jpeg', 'Dhivyadharshinir income_certif.pdf', 'Dhivyadharshinir passport_b (1).pdf', 'Dhivyadharshinir passport_b.jpeg', 'Dhivyadharshinir passport_b.pdf', 'Dhivyadharshinir passport_f (1).pdf', 'Dhivyadharshinir passport_f.jpeg', 'Dhivyadharshinir pas
# ...

# %%
#create the new directory
#carefull when create a folder ,should not again run that code because it show already exist (error)
os.mkdir('python12')
os.rename('python12','python_file12')

# %%
#rename the folder
os.rename('python1','python_file1')

# %%
#remove a directory or folder
os.remove('2.pdf')        #use to remove the file
os.rmdir('python_file1')  #use to remove the directory
